# %%
import pandas as pd

# Load the dataset we generated
df = pd.read_csv("data/tasks.csv")

# Quick look at the first few rows
df.head()
# Out:
#    task_id  task_length_minutes priority  category  due_in_days  \
# 0        1                  107      low  personal            6
# 1        2                   97      low     study            4
# 2        3                   19     high    health            9
# 3        4                  111      low  personal           13
# 4        5                   76     high    health           13
#
#    reminders_set  past_completion_rate  is_weekend  completed
# 0              1                  0.65           1          1
# 1              1                  0.20           0          0
# 2              0                  0.26           1          0
# 3              1                  0.91           1          1
# 4              0                  0.26           1          0

# %% [markdown]
# ## Inspecting dataset

# %%
print(df.shape)
# Out:
# (2000, 9)

# %%
# Check basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   task_id               2000 non-null   int64
#  1   task_length_minutes   2000 non-null   int64
#  2   priority              2000 non-null   object
#  3   category              2000 non-null   object
#  4   due_in_days           2000 non-null   int64
#  5   reminders_set         2000 non-null   int64
#  6   past_completion_rate  2000 non-null   float64
#  7   is_weekend            2000 non-null   int64
#  8   completed             2000 non-null   int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 140.8+ KB

# %%
# Statistics for numerical columns
df.describe()
# Out:
#            task_id  task_length_minutes  due_in_days  reminders_set  \
# count  2000.000000           2000.00000  2000.000000    2000.000000
# mean   1000.500000             91.35850     6.435500       0.500500
# std     577.494589             50.86046     4.014586       0.500125
# min       1.000000              5.00000     0.000000       0.000000
# 25%     500.750000             47.00000     3.000000       0.000000
# 50%    1000.500000             93.00000     6.000000       1.000000
# 75%    1500.250000            135.00000    10.000000       1.000000
# max    2000.000000            179.00000    13.000000       1.000000
#
#        past_completion_rate   is_weekend    completed
# count           2000.000000  2000.000000  2000.000000
# mean               0.590045     0.513500     0.553000
# std                0.229089     0.499943     0.497307
# min                0.200000     0.000000     0.000000
# 25%                0.390000     0.000000     0.000000
# 50%                0.580000     1.000000     1.000000
# 75%                0.780000     1.000000     1.000000
# max                1.000000     1.000000     1.000000

# %%
print(df.shape[1])
df.columns
# Out:
# 9
# Index(['task_id', 'task_length_minutes', 'priority', 'category', 'due_in_days',
#        'reminders_set', 'past_completion_rate', 'is_weekend', 'completed'],
#       dtype='object')

# %%
# Check the target balance
df['completed'].value_counts(normalize=True)
# Out:
# completed
# 1    0.553
# 0    0.447
# Name: proportion, dtype: float64
